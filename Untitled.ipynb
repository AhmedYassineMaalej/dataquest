# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

df.head()
# Out:
#       User_ID  Policy_Cancelled_Post_Purchase  Policy_Start_Year  \
# 0  USR_000000                               1               2016
# 1  USR_000001                               0               2016
# 2  USR_000002                               0               2016
# 3  USR_000003                               0               2015
# 4  USR_000004                               1               2017
#
#    Policy_Start_Week  Policy_Start_Day  Grace_Period_Extensions  \
# 0                 50                 8                        0
# 1                 10                 4                        0
# 2                  9                22                        1
# 3                 40                 3                        1
# 4                 16                17                        1
#
#    Previous_Policy_Duration_Months  Adult_Dependents  Child_Dependents  \
# 0                                3                 2               0.0
# ...

# %%
pd.read_csv('train.csv').sample(frac=0.2).to_csv('local_val.csv', index=False)
